# %%
import random
students = []
for i in range(1,51):
    students.append(
        {
            'name':f'student{i}',
            'chinese':random.randint(50,100),
            'english':random.randint(50,100),
            'math':random.randint(50,100),
            'history':random.randint(50,100),
            'health':random.randint(50,100)
        }
    )

students
# Out:
# [{'name': 'student1',
#   'chinese': 90,
#   'english': 62,
#   'math': 98,
#   'history': 80,
#   'health': 81},
#  {'name': 'student2',
#   'chinese': 75,
#   'english': 77,
#   'math': 80,
#   'history': 100,
#   'health': 90},
#  {'name': 'student3',
#   'chinese': 77,
#   'english': 64,
#   'math': 66,
#   'history': 58,
#   'health': 90},
#  {'name': 'student4',
#   'chinese': 99,
#   'english': 64,
#   'math': 85,
#   'history': 87,
#   'health': 73},
#  {'name': 'student5',
#   'chinese': 69,
#   'english': 57,
#   'math': 93,
#   'history': 95,
#   'health': 51},
#  {'name': 'student6',
#   'chinese': 68,
#   'english': 75,
#   'math': 68,
#   'history': 55,
#   'health': 94},
#  {'name': 'student7',
#   'chinese': 72,
#   'english': 69,
#   'math': 74,
#   'history': 58,
#   'health': 98},
#  {'name': 'student8',
#   'chinese': 74,
#   'english': 59,
#   'math': 64,
#   'history': 98,
#   'health': 83},
#  {'name': 'student9',
#   'chinese': 55,
#   'english': 70,
#   'math': 54,
#   'history': 81,
#   'health': 84},
#  {'name': 'student10',
#   'chinese': 86,
#   'english': 100,
#   'math': 88,
#   'history': 86,
#   'health': 72},
#  {'name': 'student11',
#   'chinese': 66,
#   'english': 67,
#   'math': 99,
#   'history': 88,
#   'health': 95},
#  {'name': 'student12',
#   'chinese': 70,
#   'english': 99,
#   'math': 86,
#   'history': 63,
#   'health': 86},
#  {'name': 'student13',
#   'chinese': 97,
#   'english': 93,
#   'math': 88,
#   'history': 55,
#   'health': 64},
#  {'name': 'student14',
#   'chinese': 54,
#   'english': 90,
#   'math': 83,
#   'history': 94,
#   'health': 66},
#  {'name': 'student15',
#   'chinese': 61,
#   'english': 64,
#   'math': 60,
#   'history': 66,
#   'health': 84},
#  {'name': 'student16',
#   'chinese': 71,
#   'english': 93,
#   'math': 77,
#   'history': 88,
#   'health': 85},
#  {'name': 'student17',
#   'chinese': 93,
#   'english': 59,
#   'math': 57,
#   'history': 90,
#   'health': 70},
#  {'name': 'student18',
#   'chinese': 88,
#   'english': 85,
#   'math': 62,
#   'history': 100,
#   'health': 100},
#  {'name': 'student19',
#   'chinese': 82,
#   'english': 58,
#   'math': 89,
#   'history': 87,
#   'health': 70},
#  {'name': 'student20',
#   'chinese': 81,
#   'english': 71,
#   'math': 87,
#   'history': 52,
#   'health': 80},
#  {'name': 'student21',
#   'chinese': 87,
#   'english': 74,
#   'math': 61,
#   'history': 64,
#   'health': 74},
#  {'name': 'student22',
#   'chinese': 57,
#   'english': 90,
#   'math': 71,
#   'history': 97,
#   'health': 95},
#  {'name': 'student23',
#   'chinese': 93,
#   'english': 52,
#   'math': 86,
#   'history': 91,
#   'health': 93},
#  {'name': 'student24',
#   'chinese': 83,
#   'english': 97,
#   'math': 53,
#   'history': 98,
#   'health': 63},
#  {'name': 'student25',
#   'chinese': 85,
#   'english': 98,
#   'math': 93,
#   'history': 73,
#   'health': 67},
#  {'name': 'student26',
#   'chinese': 68,
#   'english': 89,
#   'math': 77,
#   'history': 86,
#   'health': 65},
#  {'name': 'student27',
#   'chinese': 97,
#   'english': 98,
#   'math': 94,
#   'history': 63,
#   'health': 71},
#  {'name': 'student28',
#   'chinese': 80,
#   'english': 56,
#   'math': 75,
#   'history': 95,
#   'health': 69},
#  {'name': 'student29',
#   'chinese': 87,
#   'english': 94,
#   'math': 66,
#   'history': 91,
#   'health': 66},
#  {'name': 'student30',
#   'chinese': 59,
#   'english': 79,
#   'math': 84,
#   'history': 74,
#   'health': 100},
#  {'name': 'student31',
#   'chinese': 72,
#   'english': 91,
#   'math': 51,
#   'history': 87,
#   'health': 67},
#  {'name': 'student32',
#   'chinese': 90,
#   'english': 50,
#   'math': 96,
#   'history': 74,
#   'health': 55},
#  {'name': 'student33',
#   'chinese': 57,
#   'english': 80,
#   'math': 50,
#   'history': 71,
#   'health': 100},
#  {'name': 'student34',
#   'chinese': 90,
#   'english': 61,
#   'math': 79,
#   'history': 61,
#   'health': 89},
#  {'name': 'student35',
#   'chinese': 50,
#   'english': 100,
#   'math': 58,
#   'history': 57,
#   'health': 79},
#  {'name': 'student36',
#   'chinese': 70,
#   'english': 52,
#   'math': 66,
#   'history': 80,
#   'health': 98},
#  {'name': 'student37',
#   'chinese': 88,
#   'english': 81,
#   'math': 72,
#   'history': 78,
#   'health': 60},
#  {'name': 'student38',
#   'chinese': 82,
#   'english': 69,
#   'math': 85,
#   'history': 50,
#   'health': 76},
#  {'name': 'student39',
#   'chinese': 55,
#   'english': 58,
#   'math': 99,
#   'history': 76,
#   'health': 72},
#  {'name': 'student40',
#   'chinese': 68,
#   'english': 60,
#   'math': 83,
#   'history': 76,
#   'health': 86},
#  {'name': 'student41',
#   'chinese': 68,
#   'english': 79,
#   'math': 71,
#   'history': 87,
#   'health': 86},
#  {'name': 'student42',
#   'chinese': 68,
#   'english': 51,
#   'math': 83,
#   'history': 94,
#   'health': 82},
#  {'name': 'student43',
#   'chinese': 61,
#   'english': 58,
#   'math': 91,
#   'history': 69,
#   'health': 51},
#  {'name': 'student44',
#   'chinese': 85,
#   'english': 70,
#   'math': 70,
#   'history': 75,
#   'health': 74},
#  {'name': 'student45',
#   'chinese': 60,
#   'english': 100,
#   'math': 93,
#   'history': 85,
#   'health': 58},
#  {'name': 'student46',
#   'chinese': 96,
#   'english': 69,
#   'math': 91,
#   'history': 84,
#   'health': 53},
#  {'name': 'student47',
#   'chinese': 92,
#   'english': 86,
#   'math': 91,
#   'history': 62,
#   'health': 79},
#  {'name': 'student48',
#   'chinese': 85,
#   'english': 64,
#   'math': 88,
#   'history': 99,
#   'health': 100},
#  {'name': 'student49',
#   'chinese': 85,
#   'english': 98,
#   'math': 56,
#   'history': 67,
#   'health': 55},
#  {'name': 'student50',
#   'chinese': 50,
#   'english': 69,
#   'math': 51,
#   'history': 67,
#   'health': 75}]

# %%
# 將 students 列表轉換為字串
students_str = '\n'.join([
    f"姓名:{student['name']}, "
    f"國文:{student['chinese']}, "
    f"英文:{student['english']}, "
    f"數學:{student['math']}, "
    f"歷史:{student['history']}, "
    f"健康:{student['health']}"
    for student in students
])

print(students_str)
# Out:
# 姓名:student1, 國文:77, 英文:91, 數學:88, 歷史:52, 健康:68
# 姓名:student2, 國文:69, 英文:89, 數學:68, 歷史:68, 健康:95
# 姓名:student3, 國文:57, 英文:80, 數學:91, 歷史:97, 健康:96
# 姓名:student4, 國文:77, 英文:68, 數學:76, 歷史:54, 健康:71
# 姓名:student5, 國文:54, 英文:58, 數學:100, 歷史:82, 健康:58
# 姓名:student6, 國文:91, 英文:100, 數學:70, 歷史:67, 健康:90
# 姓名:student7, 國文:66, 英文:98, 數學:70, 歷史:82, 健康:60
