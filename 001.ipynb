# %%
import requests
web = requests.get('https://water.taiwanstat.com/')
web.encoding = 'utf-8'
print(web.text)
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" lang="zh-TW"><head><meta property="og:title" content="台灣水庫即時水情"><meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta property="og:site_name" content="台灣水庫即時水情"><meta property="og:description" content="台灣水庫即時水情-視覺化, 即時蓄水量、水位變化..."><meta property="og:image" content="http://i.imgur.com/04AFcnA.png"><meta property="og:image:type" content="image/png"><meta name="author" content="Chi-Hsuan Huang"><meta name="citation_authors" content="Po-An Yang"><meta name="description" content="台灣水庫即時水情-視覺化, 即時蓄水量、水位變化"><title>台灣水庫即時水情</title><meta property="og:locale" content="zh_TW"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="icon" type="image/png" href="//static.taiwanstat.com/favicon.ico"><link rel="shortcut icon" href="//static.taiwanstat.com/favicon.ico" type="image/x-icon"><link rel="stylesheet" href="//static.taiwanstat.com/css/style.min.css"><link rel="stylesheet" href="//storage.googl
# ...

# %%
import requests
web = requests.get('https://data.kcg.gov.tw/dataset/6f29f6f4-2549-4473-aa90-bf60d10895dc/resource/30dfc2cf-17b5-4a40-8bb7-c511ea166bd3/download/lightrailtraffic.json')
print(web.json())
# Out:
# [{'年': 107, '月': 1, '總運量': 275360, '日均運量': 8883, '假日均運量': 15132, '月台上刷卡日均筆數': 1734.2, '車上刷卡日均筆數': 5495.9, '售票機日均筆數': 1516.8, '補票日均筆數': 9.4, '團體票日均筆數': 126.3, '人工售票日均筆數': '', 'QR-CODE日均筆數': '', '備註': ''}, {'年': 107, '月': 2, '總運量': 413815, '日均運量': 14779, '假日均運量': 20738, '月台上刷卡日均筆數': 3854.9, '車上刷卡日均筆數': 9039.8, '售票機日均筆數': 1754.9, '補票日均筆數': 11.9, '團體票日均筆數': 117.7, '人工售票日均筆數': '', 'QR-CODE日均筆數': '', '備註': ''}, {'年': 107, '月': 3, '總運量': 209783, '日均運量': 6767, '假日均運量': 13198, '月台上刷卡日均筆數': 1413.2, '車上刷卡日均筆數': 4487.5, '售票機日均筆數': 660.7, '補票日均筆數': 6.5, '團體票日均筆數': 199.2, '人工售票日均筆數': '', 'QR-CODE日均筆數': '', '備註': ''}, {'年': 107, '月': 4, '總運量': 283651, '日均運量': 9455, '假日均運量': 16656, '月台上刷卡日均筆數': 2183.7, '車上刷卡日均筆數': 6013.8, '售票機日均筆數': 944.5, '補票日均筆數': 6.3, '團體票日均筆數': 306.8, '人工售票日均筆數': '', 'QR-CODE日均筆數': '', '備註': ''}, {'年': 107, '月': 5, '總運量': 206325, '日均運量': 6656, '假日均運量': 11573, '月台上刷卡日均筆數': 1385.8, '車上刷卡日均筆數': 4331.5, '售票機日均筆數': 558.6, '補票日均筆數': 7.1, '團體票日均筆數': 372.7, '人工售票日均筆數': '', 'QR-CODE日均筆數'
# ...

# %%
import requests
web = requests.get('https://data.kcg.gov.tw/12345')
if web.status_code == 404:
    print('找不到網頁')
# Out:
# 找不到網頁

# %%
import requests
params = {'你的名字是：':'oxxo','age':'18'}
web = requests.get('https://script.googleusercontent.com/macros/echo?user_content_key=t4BmpnelL7iP7ul6uxXzyTCL4aE3X03JLQaLhWX67Yij3SQWCBSWvqkvAlZ3LjNxIYDuQ7mdm0rgv3dJyaa4lw9Qtn2ZOYSGm5_BxDlH2jW0nuo2oDemN9CCS2h10ox_1xSncGQajx_ryfhECjZEnEDDvMZe6lF4gk9CPsvwzdQhr0QaUyzbZRoBP83nGZb9vmw91hF5cbjjEBhvSJcrCbxy_u9Yn2NR&lib=MJYIcJTnM8_xVwJDUMP83GT6nD5PpjW7q', params=params)
print(web.text)
# Out:
# 你的名字是：undefined，年紀：undefined 歲。
